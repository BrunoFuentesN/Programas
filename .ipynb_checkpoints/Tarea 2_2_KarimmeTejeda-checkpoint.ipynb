# %% [markdown]
# # TAREA - Integración montecarlo

# %% [markdown]
# 1. Realizar las siguientes integrales. Poner los resultados en una tabla cuyas filas correspondan a la cantidad de términos utilizados en la aproximación (usar 10, 100, 1000, 10000 y 100000 términos) y cuyas columnas correspondan a las funciones.
#     + $\int_{1}^{3} e^{x}\log(x)\text{d}x$.
#     + $\int_1^3 \sin(x)\ln(x) \text{d}x$

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
N = np.logspace(1,5,5)
tabla=pd.DataFrame(columns=['f1','f2'],index=N)
def f1(x):
    return np.exp(x)*np.log(x)
def f2(x):
    return np.sin(x)*np.log(x)

def montecarlo1(f,a,b,N):
    u=np.random.uniform(a,b,size=N)
    y=f(u)
    return np.mean(y)*(b-a)
for n in N:
    tabla.loc[n,'f1']=montecarlo1(f1,1,3,int(n))
    tabla.loc[n,'f2']=montecarlo1(f2,1,3,int(n))
tabla
# Out:
#                f1        f2
# 10.0      23.1138  0.824041
# 100.0     16.5382  0.913169
# 1000.0    13.8134    0.8835
# 10000.0   14.2569  0.874468
# 100000.0  13.9745  0.869804

# %% [markdown]
# 2. Aproximar el área de la región descrita por
#
# $$x^2+2y^2\leq-2x+8y-7$$
#
# Poner los resultados en una tabla cuyas filas correspondan a la cantidad de términos utilizados en la aproximación (usar 10, 100, 1000, 10000 y 100000 términos) y en las columnas el valor de aproximación y el error relativo.
#
# Definir unos límites adecuados $a_1$, $b_1$, $a_2$ y $b_2$, para la región $R=\left[a_1,b_1\right]\times\left[a_2,b_2\right]$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def montecarlo2(region,xmin,xmax,ymin,ymax,N):
    x=np.random.uniform(xmin,xmax,N)
    y=np.random.uniform(ymin,ymax,N)
    B=region(x,y)
    AR=(xmax-xmin)*(ymax-ymin)
    return np.mean(B)*AR

# %%
def region(x,y):
    return x**2+2*y**2<-2*x+8*y-7

#Averiguar los límites de integración
x=np.random.uniform(-2.5,0.45,100)  #Proponemos límites para 'x'
y=np.random.uniform(1,3,100)  #Proponemos límites para 'y'
X,Y=np.meshgrid(x,y)  #Creamos pares coordenados para abarcar todo el espacio posible
plt.scatter(X,Y,c=~region(X,Y),cmap='gray')   #Graficamos todo el espacio especificando el color según la región de interés
plt.grid()

# %% [markdown]
# Se encontraron los límites para $x$ de $-2.5$ a $0.45$ y para $y$ de $1$ a $3$

# %%
import pandas as pd

# %%
N=np.logspace(1,5,5)
tabla=pd.DataFrame(columns=['Aproximación','Error'],index=N)

# %%
AR=(0.45-(-2.5))*(3-(-1)) #Area conocida
for n in N:
    tabla.loc[n,'Aproximación']=montecarlo2(region,-2.5,0.45,1,3,int(n))
    th=tabla['Aproximación'][n]/AR
    tabla.loc[n,'Error']=np.sqrt((1-th)/th)/np.sqrt(n)
tabla
# Out:
#          Aproximación       Error
# 10.0             5.31    0.349603
# 100.0           4.484    0.127733
# 1000.0         4.5135   0.0401793
# 10000.0       4.45509     0.01284
# 100000.0      4.44884  0.00406495
